# %%
import torch
from train import train
from lofi_model import LofiModel
from dataset import MidiDataset
import pretty_midi
import numpy as np
from config import *
print(torch.__version__)
print(torch.version.cuda)
# Out:
# c:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\venv\Lib\site-packages\pretty_midi\instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2.7.1+cu118
# 11.8

# %% [markdown]
# # Setup

# %% [markdown]
# kl weight = 0.02
# teacher forcing ratio = 0.1353

# %%
# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Dataset setup
dataset_dir = r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\dataset\transformed_dataset_3_imnstrumenty"

# Model setup
model = LofiModel()
model.to(device)
print(model)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal trainable parameters: {total_params}")
# Out:
# LofiModel(
#   (encoder): Encoder(
#     (lstm): LSTM(76, 256, batch_first=True, bidirectional=True)
#     (fc_mean): Linear(in_features=512, out_features=64, bias=True)
#     (fc_logvar): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): Decoder(
#     (lstm_cell): LSTMCell(76, 256)
#     (fc): Linear(in_features=256, out_features=76, bias=True)
#   )
#   (fc_latent_to_hidden): Linear(in_features=64, out_features=256, bias=True)
#   (fc_latent_to_cell): Linear(in_features=64, out_features=256, bias=True)
# )
#
# Total trainable parameters: 1144524

# %% [markdown]
# # TRAINING

# %%
train(model, 
        dataset_dir, 
        experiment_name="Base model - only drumms (same model more training)",
        verbose=True, 
        model_save_path = "Base model - only drumms (same model more training).pth",
        weights_pth=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\model\saved_models\progress\best so far\lofi-model_epoch400.pth",
        early_stopping=False)
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# ---WEIGHTS LOADING---
# Loading weights from: C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\model\saved_models\progress\best so far\lofi-model_epoch400.pth
# Succesfully loaded weights.
#
# Starting from epoch 0
# ____________________________________________________________
#
# Setting up datasets and dataloaders...
# Finished setting up datasets and dataloaders.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ziemmi13/lofi-vae/503a92b1d2e54b8a8b8580dd1de3df63
# ...
# STARTING TRAINING
# ...
#
# Using cuda device
#
# The datset has 110 batches
#
# Epoch [1/400]
# ...
