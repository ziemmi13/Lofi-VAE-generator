# %% [markdown]
# # Dataset sanity check

# %%
from dataset import MidiDataset
import torch
# Out:
# c:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\venv\Lib\site-packages\pretty_midi\instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
dataset = MidiDataset(verbose=True)

# %%
for i in range(5):
    tensor, seq_len, filename = dataset[i]
    print(f"File: {filename}, Length: {seq_len}, Shape: {tensor.shape}")

    dataset.visualize_midi(tensor)
# Out:
# File: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_01_Track01_wav, Length: 360, Shape: torch.Size([61, 360])
# File: MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_10_Track10_wav, Length: 360, Shape: torch.Size([61, 360])
# File: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--2, Length: 360, Shape: torch.Size([61, 360])
# File: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--3, Length: 360, Shape: torch.Size([61, 360])
# File: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--4, Length: 360, Shape: torch.Size([61, 360])
