# %% [markdown]
# # Dataset sanity check

# %%
from dataset import MidiDataset
import torch
# Out:
# c:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\venv\Lib\site-packages\pretty_midi\instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
dataset = MidiDataset(dataset_dir=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PROJEKT ZESPOLOWY\dataset\transformed_dataset_3_imnstrumenty - mini", verbose=True)

# %%
len(dataset)
# Out:
# 323

# %%
for i in range(4):
    tensor, seq_len, filename = dataset[i]
    print(f"File: {filename}, Length: {seq_len}, Shape: {tensor.shape}")

    dataset.visualize_midi(tensor)
# Out:
# File: 00231887ed5201b0e9c2d850c38b1c16, Length: 200, Shape: torch.Size([76, 200])
# File: 009802d8213b93027c45bf861b16babf, Length: 200, Shape: torch.Size([76, 200])
# File: 02405660e58b5cbde37a844d562ac66d, Length: 200, Shape: torch.Size([76, 200])
# File: 02659e4a65538cbd815cecc27112181d, Length: 200, Shape: torch.Size([76, 200])
# File: 02736ffe2ab0c9f748dba5fba0bd5546, Length: 200, Shape: torch.Size([76, 200])
# File: 02803137350864e1784e85542f74fec7, Length: 200, Shape: torch.Size([76, 200])
# File: 028284eae0af6d7780acdaf1a71f7736, Length: 200, Shape: torch.Size([76, 200])
# File: 028758de92ec780433c2f1ae02d53da6, Length: 200, Shape: torch.Size([76, 200])
# File: 036448c8eb835cffa8d070e3ff4ac477, Length: 200, Shape: torch.Size([76, 200])
# File: 0404496c4e052d2054cbf2333ec4face, Length: 200, Shape: torch.Size([76, 200])
